# %% [markdown]
# <a href="https://colab.research.google.com/github/ProtossDragoon/paper_implementation_and_testing_tf2/blob/main/utils/Unpack_Large_Zipfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unpack Large Zipfile
#
# ## Author
#
# name : Janghoo Lee <br>
# github : https://github.com/ProtossDragoon <br>
# contact : dlwkdgn1@naver.com <br>
# circle : https://github.com/sju-coml <br>
# organization : https://web.deering.co/ <br>
# published date : Agust, 2021
#
# ## Related Notebook
#
# [Notebooks](https://github.com/ProtossDragoon/paper_implementation_and_testing_tf2/tree/main/notebooks)

# %% [markdown]
# # Environment

# %% [markdown]
# ## Import

# %%
import os

# %% [markdown]
# ## Global Hyper parameters

# %%
HOME_DIR = "/content/gdrive/MyDrive"
DATA_DIR = os.path.join(HOME_DIR, 'data')

GIT_USERNAME = None
GIT_EMAIL = None

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# here is my case,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TIPS
#
# - -u part controls extraction only if new/necessary. It is important if suddenly you lose connection or hardware switches off.
# - -d creates the directory and extracted files are stored there.
# - -q quite mode

# %%
ZIPFILE_EXISTS_DIR = os.path.join(DATA_DIR, 'pedestrian', 'surface_masking')
assert os.path.exists(ZIPFILE_EXISTS_DIR)
# %cd {ZIPFILE_EXISTS_DIR}
# %ls -al

# !for i in *.zip; do unzip -u -q $i;done
# %ls
# Out:
# /content/gdrive/MyDrive/data/pedestrian/surface_masking
# total 52211103
# -rw------- 1 root root 10910657364 Aug 24 06:33 Surface_1.zip
# -rw------- 1 root root 10875592930 Aug 24 06:48 Surface_2.zip
# -rw------- 1 root root 10578316497 Aug 24 07:04 Surface_3.zip
# -rw------- 1 root root 10561415888 Aug 24 07:21 Surface_4.zip
# -rw------- 1 root root 10538184950 Aug 24 07:38 Surface_5.zip

# %%
ZIPFILE_EXISTS_DIR = os.path.join(DATA_DIR, 'pedestrian', 'polygon_segmentation')
assert os.path.exists(ZIPFILE_EXISTS_DIR)
# %cd {ZIPFILE_EXISTS_DIR}
# %ls -al

# !for i in *.zip; do unzip -u -q $i;done
# %ls
# Out:
# /content/gdrive/MyDrive/data/pedestrian/polygon_segmentation
# total 140845199
# -rw------- 1 root root  9745052470 Aug 24 15:07 Polygon_10_new.zip
# -rw------- 1 root root 10264411421 Aug 24 15:22 Polygon_11_new.zip
# -rw------- 1 root root 10102686605 Aug 24 15:37 Polygon_12_new.zip
# -rw------- 1 root root  9687714508 Aug 24 15:51 Polygon_13_new.zip
# -rw------- 1 root root 10542619507 Aug 24 16:07 Polygon_14_new.zip
# -rw------- 1 root root 11006750363 Aug 24 07:54 Polygon_1_new.zip
# -rw------- 1 root root 10749458264 Aug 24 08:10 Polygon_2_new.zip
# -rw------- 1 root root 10489079412 Aug 24 08:26 Polygon_3_new.zip
# -rw------- 1 root root 10560075483 Aug 24 12:29 Polygon_4_new.zip
# -rw------- 1 root root 11004203611 Aug 24 13:42 Polygon_5_new.zip
# -rw------- 1 root root 10116645804 Aug 24 13:58 Polygon_6_new.zip
# -rw------- 1 root root 10522186929 Aug 24 14:17 Polygon_7_new.zip
# -rw------- 1 root root  9705684281 Aug 24 14:33 Polygon_8_new.zip
# ...

# %%
ZIPFILE_EXISTS_DIR = os.path.join(DATA_DIR, 'pedestrian', 'bounding_box')
assert os.path.exists(ZIPFILE_EXISTS_DIR)
# %cd {ZIPFILE_EXISTS_DIR}
# %ls -al

# !for i in *.zip; do unzip -u -q $i;done
# %ls
# Out:
# /content/gdrive/MyDrive/data/pedestrian/bounding_box
# total 316205928
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0001/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0002/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0003/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0004/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0005/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0006/
# drwx------ 2 root root        4096 Nov 19  2020 Bbox_0007/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0008/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0009/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0010/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0011/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0012/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0013/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0014/
# drwx------ 2 root root        4096 Aug 26  2020 Bbox_0015/
# ...
